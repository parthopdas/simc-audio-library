# %%
from glob import glob
from os import path
from mutagen.id3 import ID3, ID3NoHeaderError
from datetime import datetime
import re
import json

# %%
AUDIO_DIRS = ["2010", "Blessings", "Chanting", "Daily", "Dhammapada", "Internet", "Live", "Los Angeles Course", "Old", "Pali", "Stories", "Study", "Talks", "Television", "Thai", "Visuddhimagga", "ask-a-monk"]

# %%
res = []
all_tags = set()

for audio_dir in AUDIO_DIRS:
    for file in glob(path.join('./share.sirimangalo.org/', audio_dir, '*.mp3')):
        file_base = path.basename(file)

        meta = { 
            'file': path.join(audio_dir, file_base),
            'folder': audio_dir,
            'title': '', 
            'album': '',
            'year': '',
            'comment': '',
            'date_from_filename': ''
        }
        
        # get date from filename
        try:
            s = file_base.split('_')
            
            if len(s) > 1:
                if len(s[0]) == 6 and re.match('^[0-9]{6}', s[0]):
                    meta['date_from_filename'] = datetime.strptime(s[0][:6], "%y%m%d").isoformat()[:10]
                elif len(s[0]) == 8 and re.match('^[0-9]{8}', s[0]):
                    meta['date_from_filename'] = datetime.strptime(s[0][:8], "%Y%m%d").isoformat()[:10]
        except ValueError:
            pass
        
        try:
            # get data from id3 tags
            # ref: https://static.sirimangalo.org/diraudio/Yuttadhammo/rss.php
            i3tags = ID3(file)
            
            all_tags.update(i3tags.keys())
            
            if 'TIT2' in i3tags:
                meta['title'] = i3tags['TIT2'].text[0]
                
            if 'TALB' in i3tags:
                meta['album'] = i3tags['TALB'].text[0]
                
            if 'TDRC' in i3tags:
                year = int(str(i3tags['TDRC'].text[0]))
                
                if year <= 2020:
                    meta['year'] = str(year)

            comment1 = ''
            if 'COMM::XXX' in i3tags:
                comment1 = i3tags['COMM::XXX'].text[0]

            comment2 = ''
            if 'COMM::\x00\x00\x00' in i3tags:
                comment2 = i3tags['COMM::\x00\x00\x00'].text[0]

            comment3 = ''
            if 'COMM:ID3v1 Comment:eng' in i3tags:
                comment3 = i3tags['COMM:ID3v1 Comment:eng'].text[0]
                
            comment4 = ''
            if 'COMM:ID3v1 Comment:XXX' in i3tags:
                comment4 = i3tags['COMM:ID3v1 Comment:XXX'].text[0]
            
            comment = comment2
            
            if len(comment1) > len(comment):
                comment = comment1
            
            if not comment and (comment3 or comment4):
                comment = comment4 if len(comment4) > len(comment3) else comment3

            meta['comment'] = comment

            res.append(meta)
        except ID3NoHeaderError:
            pass

# %%
res
# Out:
# [{'file': '2010/100202_WhatIsMeditation.mp3',
#   'folder': '2010',
#   'title': 'What Is Meditation?',
#   'album': '2010',
#   'year': '',
#   'comment': 'Discussion different types of meditation',
#   'date_from_filename': '2010-02-02'},
#  {'file': '2010/100204_IntroBuddhism.mp3',
#   'folder': '2010',
#   'title': 'Introduction To Buddhism',
#   'album': '2010',
#   'year': '',
#   'comment': 'An introduction to the three most important things in the Buddhist religion.',
#   'date_from_filename': '2010-02-04'},
#  {'file': '2010/100218_Walking5.mp3',
#   'folder': '2010',
#   'title': 'Benefits of Walking Meditation',
#   'album': '2010',
#   'year': '',
#   'comment': 'The five canonical benefits of walking meditation.',
#   'date_from_filename': '2010-02-18'},
#  {'file': '2010/100318_Visuddhi7.mp3',
#   'folder': '2010',
#   'title': 'Seven Stage in the Path to Purity',
#   'album': '2010',
#   'year': '',
#   'comment': 'Outline of the step-by-step path to purification outlined in the TIpitaka and expanded upon in the treatise called the Visuddhimagga, especially as it pertains to meditation practice.',
#   'date_from_filename': '2010-03-18'},
#  {'file': '2010/100114_FourTruthsGHCSL.mp3',
#   'folder': '2010',
#   'title': 'Four Noble Truths',
#   'album': '2010',
#   'year': '',
#   'comment': 'At the Center For Spiritual Living, Granada Hills, CA',
#   'date_from_filename': '2010-01-14'},
#  {'file': '2010/100214_FiveBuddhists.mp3',
#   'folder': '2010',
#   'title': 'Five Kinds of Buddhist Practitioners',
#   'album': '2010',
#   'year': '',
#   'comment': 'From the Dhammavihari Sutta on five types of Buddhist, only one of whom can be said to "dwell in the dhamma".',
#   'date_from_filename': '2010-02-14'},
#  {'file': '2010/100322_Appamada4.mp3',
#   'folder': '2010',
#   'title': 'In Line With the Teaching',
#   'album': '2010',
#   'year': '',
#   'comment': "On practicing in line with the Buddha's teaching without having to have studied all of the Tipitaka.",
#   'date_from_filename': '2010-03-22'},
#  {'file': '2010/100328_Iddhipada4.mp3',
#   'folder': '2010',
#   'title': 'The Four Iddhipada or Paths to Power',
#   'album': '2010',
#   'year': '',
#   'comment': 'The four qualities of mind needed for success, especially in meditation practice.',
#   'date_from_filename': '2010-03-28'},
#  {'file': '2010/100226_ComprehensiveKarma.mp3',
#   'folder': '2010',
#   'title': 'Overview of the Buddhist Theory of Karma',
#   'album': '2010',
#   'year': '',
#   'comment': 'On the 14 types of karmic retribution, the 12 types of karma, and the threefold karmic wheel.',
#   'date_from_filename': '2010-02-26'},
#  {'file': '2010/100216_FiveGoals.mp3',
#   'folder': '2010',
#   'title': 'Stories on the Goals of Mindfulness',
#   'album': '2010',
#   'year': '',
#   'comment': 'Some examples of how mindfulness is able to acheive its goals.',
#   'date_from_filename': '2010-02-16'},
#  {'file': '2010/100326_Anupubbikatha.mp3',
#   'folder': '2010',
#   'title': "The Buddha's Order of Teaching",
#   'album': '2010',
#   'year': '',
#   'comment': 'On the Anupubbikatha, a method of teaching often imployed by the Buddha, in which he would start with speech on basic goodness and end with talk on total freedom.',
#   'date_from_filename': '2010-03-26'},
#  {'file': '2010/100622_Wanting.mp3',
#   'folder': '2010',
#   'title': 'Wanting and Buddhism',
#   'album': '2010',
#   'year': '',
#   'comment': 'On desire for progress and enlightenment and how one should properly approach the path to Enlightenment.',
#   'date_from_filename': '2010-06-22'},
#  {'file': 'Blessings/120405_BlessingsIV.mp3',
#   'folder': 'Blessings',
#   'title': "Life's Blessings IV",
#   'album': '',
#   'year': '',
#   'comment': 'care for mother and father, good relationship with relatives, straight and blameless work, charity and righteous conduct',
#   'date_from_filename': '2012-04-05'},
#  {'file': 'Blessings/120325_evening0325.mp3',
#   'folder': 'Blessings',
#   'title': "Life's Blessings III",
#   'album': '',
#   'year': '',
#   'comment': 'much knowledge, skill, well-trained discipline, words well-spoken',
#   'date_from_filename': '2012-03-25'},
#  {'file': 'Blessings/120312_evening0312.mp3',
#   'folder': 'Blessings',
#   'title': "Life's Blessings I",
#   'album': '',
#   'year': '',
#   'comment': 'Introduction, non-association with fools, association with the wise, homage to those worthy',
#   'date_from_filename': '2012-03-12'},
#  {'file': 'Blessings/120412_blessing5.mp3',
#   'folder': 'Blessings',
#   'title': "Life's Blessings V",
#   'album': '',
#   'year': '',
#   'comment': 'abstaining, refraining from evil, giving up intoxicants, heedfulness of reality ',
#   'date_from_filename': '2012-04-12'},
#  {'file': 'Blessings/120313_evening0313.mp3',
#   'folder': 'Blessings',
#   'title': "Life's Blessings II",
#   'album': '',
#   'year': '',
#   'comment': 'a suitable dwelling, having done good, setting oneself right',
#   'date_from_filename': '2012-03-13'},
#  {'file': 'Blessings/120419_blessings6.mp3',
#   'folder': 'Blessings',
#   'title': "Life's Blessings VI",
#   'album': '',
#   'year': '',
#   'comment': 'Respect, humility, contentment, gratitude, listening to Dhamma from time to time',
#   'date_from_filename': '2012-04-19'},
#  {'file': 'Chanting/G ภาค 5 มนต์พิธี61-63.mp3',
#   'folder': 'Chanting',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': ''},
#  {'file': 'Chanting/100923_BJ2.mp3',
#   'folder': 'Chanting',
#   'title': 'Brahmajaala Sutta Cuulasiila',
#   'album': 'Chanting',
#   'year': '',
#   'comment': 'Second of 21 parts of the Brahmajaala Sutta, as part of a memorization project.',
#   'date_from_filename': '2010-09-23'},
#  {'file': 'Chanting/E ปราภวสุตตปาฐา42-46.mp3',
#   'folder': 'Chanting',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': ''},
#  {'file': 'Chanting/090901_02DhammacakkaPali.mp3',
#   'folder': 'Chanting',
#   'title': 'DhammacakkaPali',
#   'album': 'Chanting',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-09-01'},
#  {'file': 'Chanting/090901_05MaggaVibhangaSuttaPali.mp3',
#   'folder': 'Chanting',
#   'title': 'MaggaVibhangaSuttaPali',
#   'album': 'Chanting',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-09-01'},
#  {'file': 'Chanting/H มงคลสูตร,กรณี,ธัมมนิยาม64-70.mp3',
#   'folder': 'Chanting',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': ''},
#  {'file': 'Chanting/D ภาคสวดมนต์พิเศษ 25-42.mp3',
#   'folder': 'Chanting',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': ''},
#  {'file': 'Chanting/P ธัมมานุปัสสนาสติ 103-116.mp3',
#   'folder': 'Chanting',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': ''},
#  {'file': 'Chanting/K สติปัฏฐานสูตร81-83.mp3',
#   'folder': 'Chanting',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': ''},
#  {'file': 'Chanting/090901_13KaraniyaMettaPali.mp3',
#   'folder': 'Chanting',
#   'title': 'KaraniyaMettaPali',
#   'album': 'Chanting',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-09-01'},
#  {'file': 'Chanting/L กายานุปัสสนาสติ83-89.mp3',
#   'folder': 'Chanting',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': ''},
#  {'file': 'Chanting/090901_10MangalaSuttaPali.mp3',
#   'folder': 'Chanting',
#   'title': 'MangalaSuttaPali',
#   'album': 'Chanting',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-09-01'},
#  {'file': 'Chanting/C ทำวัตรเย็น 11-18,21.mp3',
#   'folder': 'Chanting',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': ''},
#  {'file': 'Chanting/110623_Blessing.mp3',
#   'folder': 'Chanting',
#   'title': 'Blessings',
#   'album': 'Chanting',
#   'year': '',
#   'comment': 'A short blessing in Pali, by request.',
#   'date_from_filename': '2011-06-23'},
#  {'file': 'Chanting/090901_03AnattalakkhanaPali.mp3',
#   'folder': 'Chanting',
#   'title': 'AnattalakkhanaPali',
#   'album': 'Chanting',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-09-01'},
#  {'file': 'Chanting/090901_11RatanaSuttaPali.mp3',
#   'folder': 'Chanting',
#   'title': 'RatanaSuttaPali',
#   'album': 'Chanting',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-09-01'},
#  {'file': 'Chanting/110714_Precepts.mp3',
#   'folder': 'Chanting',
#   'title': 'Taking Refuge and Precepts (Chant)',
#   'album': 'Chanting',
#   'year': '',
#   'comment': 'Guide to taking the three refuges and five or eight precepts (Pali Chant)',
#   'date_from_filename': '2011-07-14'},
#  {'file': 'Chanting/I ภาค6 อภิธรรม,ธัมมสังคิณี 71-80.mp3',
#   'folder': 'Chanting',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': ''},
#  {'file': 'Chanting/N เวทนานุปัสสนาสติ 98-100.mp3',
#   'folder': 'Chanting',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': ''},
#  {'file': 'Chanting/090901_01aPreliminaryHomage.mp3',
#   'folder': 'Chanting',
#   'title': 'aPreliminaryHomage',
#   'album': 'Chanting',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-09-01'},
#  {'file': 'Chanting/F ภาค4บทพิจารณาฯ47-59.mp3',
#   'folder': 'Chanting',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': ''},
#  {'file': 'Chanting/B ทำวัตรเช้า 1-9,19.mp3',
#   'folder': 'Chanting',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': ''},
#  {'file': 'Chanting/O จิตานุปัสสยาสติ 100-103.mp3',
#   'folder': 'Chanting',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': ''},
#  {'file': 'Chanting/J สติปัฏฐานสูตร81-83.mp3',
#   'folder': 'Chanting',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': ''},
#  {'file': 'Chanting/A เสียงต้น 0-1.mp3',
#   'folder': 'Chanting',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': ''},
#  {'file': 'Chanting/Mahapatthana.mp3',
#   'folder': 'Chanting',
#   'title': 'Mahapatthana Matika',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': ''},
#  {'file': 'Chanting/M กายานุปัสสนา 90-98.mp3',
#   'folder': 'Chanting',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': ''},
#  {'file': 'Chanting/090901_01bInvitingAngels.mp3',
#   'folder': 'Chanting',
#   'title': 'bInvitingAngels',
#   'album': 'Chanting',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-09-01'},
#  {'file': 'Chanting/Sanku Morning Chanting.mp3',
#   'folder': 'Chanting',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': ''},
#  {'file': 'Chanting/090901_04AdittapariyayaPali.mp3',
#   'folder': 'Chanting',
#   'title': 'AdittapariyayaPali',
#   'album': 'Chanting',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-09-01'},
#  {'file': 'Chanting/110810_aciram.mp3',
#   'folder': 'Chanting',
#   'title': 'Funeral Reflection',
#   'album': 'Chanting',
#   'year': '',
#   'comment': "A short reflection to be made at someone's funeral.",
#   'date_from_filename': '2011-08-10'},
#  {'file': 'Daily/120305_evening0305.mp3',
#   'folder': 'Daily',
#   'title': 'Simple Truth',
#   'album': '',
#   'year': '',
#   'comment': 'Evening Talk, March 5th',
#   'date_from_filename': '2012-03-05'},
#  {'file': 'Daily/120308_evening0308.mp3',
#   'folder': 'Daily',
#   'title': "Ten Meditator's Perceptions",
#   'album': '',
#   'year': '',
#   'comment': 'Evening Talk, March 8th',
#   'date_from_filename': '2012-03-08'},
#  {'file': 'Daily/120208_evening9f.mp3',
#   'folder': 'Daily',
#   'title': 'The Essential',
#   'album': '',
#   'year': '',
#   'comment': 'Evening Talk, Feb 9, 2012',
#   'date_from_filename': '2012-02-08'},
#  {'file': 'Daily/120222_evening.mp3',
#   'folder': 'Daily',
#   'title': 'Radiant Mind',
#   'album': '',
#   'year': '',
#   'comment': 'Daily Talk, Feb 22, 2012',
#   'date_from_filename': '2012-02-22'},
#  {'file': 'Daily/120224_evening.mp3',
#   'folder': 'Daily',
#   'title': 'One Thing Wholesome and Unwholesome',
#   'album': '',
#   'year': '',
#   'comment': 'Daily talk, Feb 24, 2012',
#   'date_from_filename': '2012-02-24'},
#  {'file': 'Daily/130422_training.mp3',
#   'folder': 'Daily',
#   'title': 'Meditation Training',
#   'album': '',
#   'year': '',
#   'comment': 'Talk on basic meditation practice of mindfulness based on the three trainings of the Buddha',
#   'date_from_filename': '2013-04-22'},
#  {'file': 'Daily/130325_Saraniya.mp3',
#   'folder': 'Daily',
#   'title': 'Memorable Dhammas',
#   'album': '',
#   'year': '',
#   'comment': 'Evening talk at Parideha Forest Monastery on the Saraniya Dhamma',
#   'date_from_filename': '2013-03-25'},
#  {'file': 'Daily/120210_eveningf10.mp3',
#   'folder': 'Daily',
#   'title': 'Bojjhanga - Factors of Enlightenment',
#   'album': '',
#   'year': '',
#   'comment': 'Daily Talk, February 10, 2012',
#   'date_from_filename': '2012-02-10'},
#  {'file': 'Daily/130212_TruthOfSuffering.mp3',
#   'folder': 'Daily',
#   'title': 'The Truth of Suffering',
#   'album': '',
#   'year': '2013',
#   'comment': 'Evening talk on four ways of looking at the concept of suffering.',
#   'date_from_filename': '2013-02-12'},
#  {'file': 'Daily/130328_buddhist.mp3',
#   'folder': 'Daily',
#   'title': 'Being Buddhist',
#   'album': '',
#   'year': '',
#   'comment': 'Evening talk on being a true Buddhist.',
#   'date_from_filename': '2013-03-28'},
#  {'file': 'Daily/130716_apamada.mp3',
#   'folder': 'Daily',
#   'title': 'Vigilance',
#   'album': '',
#   'year': '',
#   'comment': 'Evening talk on vigilance from a practical perspective',
#   'date_from_filename': '2013-07-16'},
#  {'file': 'Daily/120307_evening0307.mp3',
#   'folder': 'Daily',
#   'title': 'Celebrating A Buddhist Holiday',
#   'album': '',
#   'year': '',
#   'comment': 'Evening Talk, March 7th',
#   'date_from_filename': '2012-03-07'},
#  {'file': 'Daily/130330_good_evil.mp3',
#   'folder': 'Daily',
#   'title': 'Good and Evil',
#   'album': '',
#   'year': '',
#   'comment': 'On the meanings of good and evil in Buddhism',
#   'date_from_filename': '2013-03-30'},
#  {'file': 'Daily/130213_ThisMoment.mp3',
#   'folder': 'Daily',
#   'title': 'This Moment',
#   'album': '',
#   'year': '2013',
#   'comment': "Evening talk on why we shouldn't let the moment pass us by.",
#   'date_from_filename': '2013-02-13'},
#  {'file': 'Daily/130218_TenUpakilesa.mp3',
#   'folder': 'Daily',
#   'title': 'When Good Things Get In The Way',
#   'album': '',
#   'year': '2013',
#   'comment': 'Evening talk on the ten imperfections of insight.',
#   'date_from_filename': '2013-02-18'},
#  {'file': 'Daily/120221_evening.mp3',
#   'folder': 'Daily',
#   'title': 'A Proper Grasp',
#   'album': '',
#   'year': '',
#   'comment': 'Evening talk, Feb 21',
#   'date_from_filename': '2012-02-21'},
#  {'file': 'Daily/120209_eveningf9.mp3',
#   'folder': 'Daily',
#   'title': 'Mara',
#   'album': '',
#   'year': '',
#   'comment': 'Evening Talk, February 9, 2012',
#   'date_from_filename': '2012-02-09'},
#  {'file': 'Daily/130221_TenPerceptions.mp3',
#   'folder': 'Daily',
#   'title': 'Ten Perceptions',
#   'album': '',
#   'year': '2013',
#   'comment': 'Evening talk on the ten perceptions of the Girimananda Sutta',
#   'date_from_filename': '2013-02-21'},
#  {'file': 'Daily/130214_FourMisunderstandings.mp3',
#   'folder': 'Daily',
#   'title': 'Four Misunderstandings',
#   'album': '',
#   'year': '2013',
#   'comment': 'Evening talk on the four Vipallāsa and how they relate to the four Satipaṭṭhānā.',
#   'date_from_filename': '2013-02-14'},
#  {'file': 'Daily/120208_morning8f.mp3',
#   'folder': 'Daily',
#   'title': 'Reasons for Practicing Satipatthana',
#   'album': '',
#   'year': '',
#   'comment': 'Morning meditation talk, Feb 8th, 2012',
#   'date_from_filename': '2012-02-08'},
#  {'file': 'Daily/120306_evening0306.mp3',
#   'folder': 'Daily',
#   'title': 'Beyond God',
#   'album': '',
#   'year': '',
#   'comment': 'Daily Talk, March 6',
#   'date_from_filename': '2012-03-06'},
#  {'file': 'Daily/120309_evening0309.mp3',
#   'folder': 'Daily',
#   'title': 'What We Practice For',
#   'album': '',
#   'year': '',
#   'comment': 'Daily Talk, March 9',
#   'date_from_filename': '2012-03-09'},
#  {'file': 'Daily/130401_nature.mp3',
#   'folder': 'Daily',
#   'title': 'Back To Nature',
#   'album': '',
#   'year': '',
#   'comment': 'Evening talk on the idea of nature in Buddhism',
#   'date_from_filename': '2013-04-01'},
#  {'file': 'Daily/130220_BeliefReality.mp3',
#   'folder': 'Daily',
#   'title': 'Belief In Reality',
#   'album': '',
#   'year': '2013',
#   'comment': 'Evening talk on reality and belief.',
#   'date_from_filename': '2013-02-20'},
#  {'file': 'Daily/120220_evening.mp3',
#   'folder': 'Daily',
#   'title': 'The Most Useful Thing',
#   'album': '',
#   'year': '',
#   'comment': 'Evening Talk, Feb 20',
#   'date_from_filename': '2012-02-20'},
#  {'file': 'Daily/130222_BahiyaPaticca.mp3',
#   'folder': 'Daily',
#   'title': 'Bahiya Sutta and Paticcasamuppada',
#   'album': '',
#   'year': '2013',
#   'comment': 'Evening chanting and talk on the subject of what was chanted.',
#   'date_from_filename': '2013-02-22'},
#  {'file': 'Daily/130720_bodhipakkhiya.mp3',
#   'folder': 'Daily',
#   'title': 'Dhammas That Facilitate Awakening',
#   'album': '',
#   'year': '',
#   'comment': 'Talk on the Bodhi-pakkiya-dhamma from a practical perspective.',
#   'date_from_filename': '2013-07-20'},
#  {'file': 'Dhammapada/130427_dhp48.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 48',
#   'album': '',
#   'year': '',
#   'comment': "Under Death's Power",
#   'date_from_filename': '2013-04-27'},
#  {'file': 'Dhammapada/111105_dhp-18.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 18: Delighting Here and Hereafter',
#   'album': '',
#   'year': '',
#   'comment': '#13 in a series on the Dhammapada, a set of verse teachings of the Buddha, including explanation of the Pali verse, a synopsis of the background story and application of the teaching to our practice.',
#   'date_from_filename': '2011-11-05'},
#  {'file': 'Dhammapada/130315_dhp43.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 43',
#   'album': '',
#   'year': '',
#   'comment': ' Better Than A Blood Relative',
#   'date_from_filename': '2013-03-15'},
#  {'file': 'Dhammapada/120223_dhp-30.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 30',
#   'album': '',
#   'year': '',
#   'comment': 'The Vigilance of the Gods',
#   'date_from_filename': '2012-02-23'},
#  {'file': 'Dhammapada/091104_EndToEnmity.mp3',
#   'folder': 'Dhammapada',
#   'title': 'An End To Enmity',
#   'album': 'Dhammapada',
#   'year': '',
#   'comment': 'Dhammapada Verses 3-5',
#   'date_from_filename': '2009-11-04'},
#  {'file': 'Dhammapada/110813_dhammapada6.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse Six: Those Who Know Settle Their Quarrels',
#   'album': '',
#   'year': '',
#   'comment': '#5 in the series on the Dhammapada, a set of verse teachings of the Buddha, including explanation of the Pali verse, a synopsis of the background story and application of the teaching to our practice.',
#   'date_from_filename': '2011-08-13'},
#  {'file': 'Dhammapada/131122_dhp_64.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammpada Verse 64',
#   'album': '',
#   'year': '',
#   'comment': 'A Spoon Cannot Taste the Soup',
#   'date_from_filename': '2013-11-22'},
#  {'file': 'Dhammapada/130727_dhp56.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 56',
#   'album': '',
#   'year': '',
#   'comment': 'Wafting to the Gods',
#   'date_from_filename': '2013-07-27'},
#  {'file': 'Dhammapada/120414_dhp37.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 37',
#   'album': '',
#   'year': '',
#   'comment': 'Subduing the Wild Mind',
#   'date_from_filename': '2012-04-14'},
#  {'file': 'Dhammapada/120808_dhp41.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 41',
#   'album': '',
#   'year': '',
#   'comment': 'Like a Log',
#   'date_from_filename': '2012-08-08'},
#  {'file': 'Dhammapada/110917_dhammapada-11-12.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verses 11 and 12: Essential and Unessential',
#   'album': '',
#   'year': '',
#   'comment': '#8 in a series on the Dhammapada, a set of verse teachings of the Buddha, including explanation of the Pali verse, a synopsis of the background story and application of the teaching to our practice.',
#   'date_from_filename': '2011-09-17'},
#  {'file': 'Dhammapada/130326_dhp44_45.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verses 44-45',
#   'album': '',
#   'year': '',
#   'comment': 'Who Will Overcome This Earth?',
#   'date_from_filename': '2013-03-26'},
#  {'file': 'Dhammapada/120426_dhp-38-39.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verses 38 and 39',
#   'album': '',
#   'year': '',
#   'comment': 'Settling the Mind',
#   'date_from_filename': '2012-04-26'},
#  {'file': 'Dhammapada/131011_dhp58_59.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verses 58 and 59',
#   'album': '',
#   'year': '',
#   'comment': 'Unsoiled by filth',
#   'date_from_filename': '2013-10-11'},
#  {'file': 'Dhammapada/131115_dhp63.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 63',
#   'album': '',
#   'year': '',
#   'comment': 'Wise Know When They Are Foolish',
#   'date_from_filename': '2013-11-15'},
#  {'file': 'Dhammapada/131004_dhp57.mts.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 57',
#   'album': '',
#   'year': '',
#   'comment': 'Where Evil Cannot Find You',
#   'date_from_filename': '2013-10-04'},
#  {'file': 'Dhammapada/110809_dhp3_4.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verses 3,4',
#   'album': 'Dhammapada',
#   'year': '',
#   'comment': '#3 in my series on the Dhammapada, a set of verse teachings of the Buddha, including explanation of the Pali verse, a synopsis of the background story and application of the teaching to our practice.',
#   'date_from_filename': '2011-08-09'},
#  {'file': 'Dhammapada/130220_Dhammapada42.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 42: Worse Than an Enemy',
#   'album': '',
#   'year': '',
#   'comment': 'Whatever harm an enemy may do to an enemy, or a hater to a hater, an ill-directed mind inflicts on oneself a greater harm.',
#   'date_from_filename': '2013-02-20'},
#  {'file': 'Dhammapada/111229_dhp-25.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 25',
#   'album': '',
#   'year': '',
#   'comment': 'An Island Above the Flood',
#   'date_from_filename': '2011-12-29'},
#  {'file': 'Dhammapada/111102_dhp-15.mp4.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 15: Sorrow of an Evil-Doer',
#   'album': '',
#   'year': '',
#   'comment': '#10 in a series on the Dhammapada, a set of verse teachings of the Buddha, including explanation of the Pali verse, a synopsis of the background story and application of the teaching to our practice.',
#   'date_from_filename': '2011-11-02'},
#  {'file': 'Dhammapada/120326_dhp-31-32.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verses 31 & 32',
#   'album': '',
#   'year': '',
#   'comment': 'Burn Like A Fire, Near to Freedom',
#   'date_from_filename': '2012-03-26'},
#  {'file': 'Dhammapada/110807_dhp2.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse Two: Happiness Follows a Pure Mind',
#   'album': 'Dhammapada',
#   'year': '',
#   'comment': '#2 in my series on the Dhammapada, a set of verse teachings of the Buddha, including explanation of the Pali verse, a synopsis of the background story and application of the teaching to our practice.',
#   'date_from_filename': '2011-08-07'},
#  {'file': 'Dhammapada/120106_dhp-28.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 28',
#   'album': '',
#   'year': '',
#   'comment': 'Seeing The World From Above',
#   'date_from_filename': '2012-01-06'},
#  {'file': 'Dhammapada/130714_dhp54_55.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verses 54 and 55',
#   'album': '',
#   'year': '',
#   'comment': 'Against The Wind',
#   'date_from_filename': '2013-07-14'},
#  {'file': 'Dhammapada/131129_dhp65.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 65',
#   'album': '',
#   'year': '',
#   'comment': 'As The Tongue Tastes the Soup',
#   'date_from_filename': '2013-11-29'},
#  {'file': 'Dhammapada/111111_dhp-24.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 24: Glory to the Mindful',
#   'album': '',
#   'year': '',
#   'comment': '#16 in a series on the Dhammapada, a set of verse teachings of the Buddha, including explanation of the Pali verse, a synopsis of the background story and application of the teaching to our practice.',
#   'date_from_filename': '2011-11-11'},
#  {'file': 'Dhammapada/120411_dhp-36.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 36',
#   'album': '',
#   'year': '',
#   'comment': 'Take Care of One Thing',
#   'date_from_filename': '2012-04-11'},
#  {'file': 'Dhammapada/130329_dhp46.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 46',
#   'album': '',
#   'year': '',
#   'comment': 'Like a bubble or a mirage.',
#   'date_from_filename': '2013-03-29'},
#  {'file': 'Dhammapada/120801_dhp40.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 40',
#   'album': '',
#   'year': '',
#   'comment': 'Fortifying the Mind',
#   'date_from_filename': '2012-08-01'},
#  {'file': 'Dhammapada/111107_dhp-19-20.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verses 19 and 20: Who Partakes in the Fruit',
#   'album': '',
#   'year': '',
#   'comment': '#14 in a series on the Dhammapada, a set of verse teachings of the Buddha, including explanation of the Pali verse, a synopsis of the background story and application of the teaching to our practice.',
#   'date_from_filename': '2011-11-07'},
#  {'file': 'Dhammapada/130614_dhp50.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 50: Oversee Yourself',
#   'album': '',
#   'year': '',
#   'comment': 'Oversee Yourself.',
#   'date_from_filename': '2013-06-14'},
#  {'file': 'Dhammapada/111101_dhp-13-14.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verses 13 and 14: Mind Like a Well-thatched Roof',
#   'album': '',
#   'year': '',
#   'comment': '#9 in a series on the Dhammapada, a set of verse teachings of the Buddha, including explanation of the Pali verse, a synopsis of the background story and application of the teaching to our practice.',
#   'date_from_filename': '2011-11-01'},
#  {'file': 'Dhammapada/131109_dhp_62.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 62',
#   'album': '',
#   'year': '',
#   'comment': 'Not Ones Own Self',
#   'date_from_filename': '2013-11-09'},
#  {'file': 'Dhammapada/130628_dhp53.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 53',
#   'album': '',
#   'year': '',
#   'comment': 'Garlands of Flowers',
#   'date_from_filename': '2013-06-28'},
#  {'file': 'Dhammapada/110811_dhp5.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse Five: Enmity',
#   'album': 'Dhammapada',
#   'year': '',
#   'comment': '#4 in the series on the Dhammapada, a set of verse teachings of the Buddha, including explanation of the Pali verse, a synopsis of the background story and application of the teaching to our practice.',
#   'date_from_filename': '2011-08-11'},
#  {'file': 'Dhammapada/110806_dhp1.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse One: Mind Precedes All Things',
#   'album': 'Dhammapada',
#   'year': '',
#   'comment': '#1 in my series on the Dhammapada, a set of verse teachings of the Buddha, including explanation of the Pali verse, a synopsis of the background story and application of the teaching to our practice.',
#   'date_from_filename': '2011-08-06'},
#  {'file': 'Dhammapada/110825_dhammapada-7-8.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verses 7-8: Overcome By Evil Or Not',
#   'album': '',
#   'year': '',
#   'comment': '#6 in the series on the Dhammapada, a set of verse teachings of the Buddha, including explanation of the Pali verse, a synopsis of the background story and application of the teaching to our practice.',
#   'date_from_filename': '2011-08-25'},
#  {'file': 'Dhammapada/110904_dhammapada-verses-9-10.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verses Nine and Ten: Worthy of the Robe',
#   'album': '',
#   'year': '',
#   'comment': '#7 in the series on the Dhammapada, a set of verse teachings of the Buddha, including explanation of the Pali verse, a synopsis of the background story and application of the teaching to our practice.',
#   'date_from_filename': '2011-09-04'},
#  {'file': 'Dhammapada/111230_dhp-26-27.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verses 26 and 27',
#   'album': '',
#   'year': '',
#   'comment': 'Cherished Treasure',
#   'date_from_filename': '2011-12-30'},
#  {'file': 'Dhammapada/111103_dhp-16.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 16: Rejoicing Here and Hereafter',
#   'album': '',
#   'year': '',
#   'comment': '#11 in a series on the Dhammapada, a set of verse teachings of the Buddha, including explanation of the Pali verse, a synopsis of the background story and application of the teaching to our practice.',
#   'date_from_filename': '2011-11-03'},
#  {'file': 'Dhammapada/130524_dhp49f.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 49',
#   'album': '',
#   'year': '',
#   'comment': 'Leaving the Flower Unharmed',
#   'date_from_filename': '2013-05-24'},
#  {'file': 'Dhammapada/130416_dhp47.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 47',
#   'album': '',
#   'year': '',
#   'comment': 'Like a Sleeping Village',
#   'date_from_filename': '2013-04-16'},
#  {'file': 'Dhammapada/120403_dhp-33-34.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verses 33 & 34',
#   'album': '',
#   'year': '',
#   'comment': 'Straighten The Mind, Like A Fish In Water',
#   'date_from_filename': '2012-04-03'},
#  {'file': 'Dhammapada/131109_dhp_61.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 61',
#   'album': '',
#   'year': '',
#   'comment': 'No Friendship With Fools',
#   'date_from_filename': '2013-11-09'},
#  {'file': 'Dhammapada/111110_dhp-21-23.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verses 21 to 23: The Mindful Never Die',
#   'album': '',
#   'year': '',
#   'comment': '#15 in a series on the Dhammapada, a set of verse teachings of the Buddha, including explanation of the Pali verse, a synopsis of the background story and application of the teaching to our practice.',
#   'date_from_filename': '2011-11-10'},
#  {'file': 'Dhammapada/111104_dhp-17.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 17: Burning Here and Hereafter',
#   'album': '',
#   'year': '',
#   'comment': '#12 in a series on the Dhammapada, a set of verse teachings of the Buddha, including explanation of the Pali verse, a synopsis of the background story and application of the teaching to our practice.',
#   'date_from_filename': '2011-11-04'},
#  {'file': 'Dhammapada/120405_dhp-35.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 35',
#   'album': '',
#   'year': '',
#   'comment': ' The Tamed Mind Brings Happiness',
#   'date_from_filename': '2012-04-05'},
#  {'file': 'Dhammapada/120201_dhp-29.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 29',
#   'album': '',
#   'year': '',
#   'comment': 'Like A Swift Horse',
#   'date_from_filename': '2012-02-01'},
#  {'file': 'Dhammapada/131018_dhp60.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verse 60',
#   'album': '',
#   'year': '',
#   'comment': 'Wandering of Fools',
#   'date_from_filename': '2013-10-18'},
#  {'file': 'Dhammapada/130621_dhp51_52.mp3',
#   'folder': 'Dhammapada',
#   'title': 'Dhammapada Verses 51 and 52',
#   'album': '',
#   'year': '',
#   'comment': 'Scent of a Flower',
#   'date_from_filename': '2013-06-21'},
#  {'file': 'Internet/091031_MindIsChief.mp3',
#   'folder': 'Internet',
#   'title': 'Mind Is Chief',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-10-31'},
#  {'file': 'Internet/100808_Purpose.mp3',
#   'folder': 'Internet',
#   'title': '',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2010-08-08'},
#  {'file': 'Internet/130306_SLGuidedAndQuestions.mp3',
#   'folder': 'Internet',
#   'title': 'Guided Meditation and Questions',
#   'album': '',
#   'year': '2013',
#   'comment': 'Guided meditation in Second Life followed by Question and Answer period.',
#   'date_from_filename': '2013-03-06'},
#  {'file': 'Internet/101020_Anupubbikatha.mp3',
#   'folder': 'Internet',
#   'title': 'Gradual Teaching of the Buddha',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'The Anupubbikatha, or gradual teaching on charity, morality, heaven, dangers of senuality, and advantages of renunciation.',
#   'date_from_filename': '2010-10-20'},
#  {'file': 'Internet/100830_SectarianBuddhism.mp3',
#   'folder': 'Internet',
#   'title': 'Sectarian Buddhism and the Whole Elephant',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'Comparing sectarian Buddhism to the ancient parable of the blind men and the elephant (Second Life talk).',
#   'date_from_filename': '2010-08-30'},
#  {'file': 'Internet/110806_InternetGuided.mp3',
#   'folder': 'Internet',
#   'title': 'Skype Guided Group Meditation',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'Group meditation instruction and practice over Skype with a group of meditators in San Fransisco, CA, USA',
#   'date_from_filename': '2011-08-06'},
#  {'file': 'Internet/110903_skype-dhamma-talk-sept-3.mp3',
#   'folder': 'Internet',
#   'title': 'Skype Guided Meditation Session',
#   'album': '',
#   'year': '',
#   'comment': 'Teaching mindfulness meditation over Skype to a group of Buddhists in California',
#   'date_from_filename': '2011-09-03'},
#  {'file': 'Internet/090911_WayOfMindfulness.mp3',
#   'folder': 'Internet',
#   'title': '',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-09-11'},
#  {'file': 'Internet/111203_guided-meditation-dec-3.mp3',
#   'folder': 'Internet',
#   'title': 'Skype Guided Meditation, Dec 3',
#   'album': '',
#   'year': '',
#   'comment': 'Guided group meditation over the Internet with meditators in California',
#   'date_from_filename': '2011-12-03'},
#  {'file': 'Internet/100910_brahmajala.mp3',
#   'folder': 'Internet',
#   'title': 'Brahmajalasutta.m Paribbaajakakathaa',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'Recitation of the first section of the first discourse in the Sutta Pitaka, with eyes closed.',
#   'date_from_filename': '2010-09-10'},
#  {'file': 'Internet/101017_SLOct17.mp3',
#   'folder': 'Internet',
#   'title': '',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2010-10-17'},
#  {'file': 'Internet/090922_EightfoldPath.mp3',
#   'folder': 'Internet',
#   'title': 'EightfoldPath',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-09-22'},
#  {'file': 'Internet/100929_Mindfulness.mp3',
#   'folder': 'Internet',
#   'title': 'Practical Mindfulness Explained',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'On Mindfulness as a Universal Meditation Practice (Second Life Talk)',
#   'date_from_filename': '2010-09-29'},
#  {'file': 'Internet/090912_AllOfTheTaints.mp3',
#   'folder': 'Internet',
#   'title': '',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-09-12'},
#  {'file': 'Internet/100801_Truth.mp3',
#   'folder': 'Internet',
#   'title': 'Truth, Illusion and Falsehood',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'On the difference between illu',
#   'date_from_filename': '2010-08-01'},
#  {'file': 'Internet/100919_Success.mp3',
#   'folder': 'Internet',
#   'title': 'How To Succeed In Meditation',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'A guide on how to truly find success in incorporating meditation into your life for the long term.',
#   'date_from_filename': '2010-09-19'},
#  {'file': 'Internet/100915_Reaction.mp3',
#   'folder': 'Internet',
#   'title': 'Reacting vs. Experiencing',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'A talk about reacting to reality versus experiencing it, and the four kinds of partiality (Second Life Talk)',
#   'date_from_filename': '2010-09-15'},
#  {'file': 'Internet/101013_MeditativeMind.mp3',
#   'folder': 'Internet',
#   'title': 'The Meditative State of Mind',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'On the four aspects of a truly meditative state of mind (Second Life Talk).',
#   'date_from_filename': '2010-10-13'},
#  {'file': 'Internet/091019_WhatBuddhismOffers.mp3',
#   'folder': 'Internet',
#   'title': 'WhatBuddhismOffers',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-10-19'},
#  {'file': 'Internet/111112_group-meditation-nov-12.mp3',
#   'folder': 'Internet',
#   'title': 'On-Line Guided Meditation',
#   'album': '',
#   'year': '',
#   'comment': 'Teaching meditation to a group of Buddhist meditators in Los Angeles over Google Talk',
#   'date_from_filename': '2011-11-12'},
#  {'file': 'Internet/090924_HowToMeditate.mp3',
#   'folder': 'Internet',
#   'title': 'HowToMeditate',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-09-24'},
#  {'file': 'Internet/100420_PeaceLoveHappiness.mp3',
#   'folder': 'Internet',
#   'title': 'Peace, Love and Happiness',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'A talk on finding these three mental qualities within Second Life and without',
#   'date_from_filename': '2010-04-20'},
#  {'file': 'Internet/090919_SatipatthanaSutta1.mp3',
#   'folder': 'Internet',
#   'title': '',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-09-19'},
#  {'file': 'Internet/091011_SatipatthanaSutta4.mp3',
#   'folder': 'Internet',
#   'title': '',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-10-11'},
#  {'file': 'Internet/101024_QandA.mp3',
#   'folder': 'Internet',
#   'title': 'Questions and Answers',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'Teaching about meditation and answering questions in Second Life',
#   'date_from_filename': '2010-10-24'},
#  {'file': 'Internet/110829_measuring-progress.mp3',
#   'folder': 'Internet',
#   'title': "Measuring One's Progress in Meditation",
#   'album': '',
#   'year': '',
#   'comment': "Radio talk on different ways one can measure one's progress in the practice of meditation.",
#   'date_from_filename': '2011-08-29'},
#  {'file': 'Internet/100829_Buddhist.mp3',
#   'folder': 'Internet',
#   'title': 'Becoming Buddhist',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'On what it means and what it takes to become Buddhist',
#   'date_from_filename': '2010-08-29'},
#  {'file': 'Internet/090926_SatipatthanaSutta2.mp3',
#   'folder': 'Internet',
#   'title': 'SatipatthanaSutta2',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-09-26'},
#  {'file': 'Internet/100727_Bhaddekaratta.mp3',
#   'folder': 'Internet',
#   'title': 'Bhaddekaratta Sutta - One Good Day',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'On MN 131 - Bhaddekaratta Sutta and how to have a good day, according to the Buddha',
#   'date_from_filename': '2010-07-27'},
#  {'file': 'Internet/090917_WhatInsightIsNot.mp3',
#   'folder': 'Internet',
#   'title': 'WhatInsightIsNot',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-09-17'},
#  {'file': 'Internet/101219_SDR.mp3',
#   'folder': 'Internet',
#   'title': 'Sex, Drugs and Rock & Roll',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'A talk about sex, drugs and rock & roll from a practical Buddhist point of view (Second Life talk).',
#   'date_from_filename': '2010-12-19'},
#  {'file': 'Internet/090910_FundamentalsOfReality.mp3',
#   'folder': 'Internet',
#   'title': '',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-09-10'},
#  {'file': 'Internet/100829_Nibbana.mp3',
#   'folder': 'Internet',
#   'title': 'The Path to Nibbana',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'Guided meditation and discussion of Nibbana',
#   'date_from_filename': '2010-08-29'},
#  {'file': 'Internet/100504_ForRightView5.mp3',
#   'folder': 'Internet',
#   'title': 'Developent of Right View',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'Five factors important in the development of right view. ',
#   'date_from_filename': '2010-05-04'},
#  {'file': 'Internet/101010_PerceptionReality.mp3',
#   'folder': 'Internet',
#   'title': 'Perception vs. Reality',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'A talk on the sometimes radical difference between our perceptions and the truth of reality (Second Life talk).',
#   'date_from_filename': '2010-10-10'},
#  {'file': 'Internet/110814_FullMoon.mp3',
#   'folder': 'Internet',
#   'title': 'Mind Is Chief and Reality Is Experience ',
#   'album': '',
#   'year': '',
#   'comment': 'Radio talk on the full moon of August about the nature of reality, experience, and the role of the mind in our destiny.',
#   'date_from_filename': '2011-08-14'},
#  {'file': 'Internet/100829_Contentment.mp3',
#   'folder': 'Internet',
#   'title': 'Contentment',
#   'album': 'Internet',
#   'year': '',
#   'comment': "On Contentment in the Buddha's teaching",
#   'date_from_filename': '2010-08-29'},
#  {'file': 'Internet/110821_truth.mp3',
#   'folder': 'Internet',
#   'title': 'Radio Talk on Truth',
#   'album': '',
#   'year': '',
#   'comment': "Radio talk on various aspects of the Buddha's teaching including the importance of truth.",
#   'date_from_filename': '2011-08-21'},
#  {'file': 'Internet/091008_SeeingClearly.mp3',
#   'folder': 'Internet',
#   'title': 'SeeingClearly',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-10-08'},
#  {'file': 'Internet/101209_KarmaRebirth.mp3',
#   'folder': 'Internet',
#   'title': 'Karma and Rebirth',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'A talk on understanding karma and rebirth from a practical Buddhist  point of view (Second Life talk).',
#   'date_from_filename': '2010-12-09'},
#  {'file': 'Internet/130320_SLGuidedAndQuestions.mp3',
#   'folder': 'Internet',
#   'title': 'Second Life Guided Meditation',
#   'album': '',
#   'year': '2013',
#   'comment': 'Guided Meditation and Q and A at Buddha Center in Second Life',
#   'date_from_filename': '2013-03-20'},
#  {'file': 'Internet/110116_ApproachingBuddism.mp3',
#   'folder': 'Internet',
#   'title': 'Approaching Buddhism',
#   'album': 'Internet',
#   'year': '',
#   'comment': "On the various ways one might approach the Buddha's teaching.",
#   'date_from_filename': '2011-01-16'},
#  {'file': 'Internet/101205_GoingForth.mp3',
#   'folder': 'Internet',
#   'title': 'Going Forth',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'On how to truly go forth from suffering into freedom (Second Life talk).',
#   'date_from_filename': '2010-12-05'},
#  {'file': 'Internet/110714_AsalhaTalk.mp3',
#   'folder': 'Internet',
#   'title': 'Asalha Puja 2011',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'Talk on the meaning of Asalha Puja and the ceremony for taking refuge and precepts.',
#   'date_from_filename': '2011-07-14'},
#  {'file': 'Internet/111204_guided-meditation-dec-4.mp3',
#   'folder': 'Internet',
#   'title': 'Guided Meditation, Dec. 4',
#   'album': '',
#   'year': '',
#   'comment': 'Guided meditation session with a group in New York over Internet',
#   'date_from_filename': '2011-12-04'},
#  {'file': 'Internet/101003_MakingItHappen.mp3',
#   'folder': 'Internet',
#   'title': 'Making A Real Difference',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'On how to truly incorporate Buddhist meditation practice into our lives on a fundamental level.',
#   'date_from_filename': '2010-10-03'},
#  {'file': 'Internet/091030_DharmaWork.mp3',
#   'folder': 'Internet',
#   'title': 'Dharma Work',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-10-30'},
#  {'file': 'Internet/091003_SatipatthanaSutta3.mp3',
#   'folder': 'Internet',
#   'title': '',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-10-03'},
#  {'file': 'Internet/100901_Dhammavinaya.mp3',
#   'folder': 'Internet',
#   'title': 'What is Dhamma Vinaya',
#   'album': 'Internet',
#   'year': '',
#   'comment': "How to tell what is and what isn't the Buddha's teaching (Dhamma-vinaya).",
#   'date_from_filename': '2010-09-01'},
#  {'file': 'Internet/090915_LivingByDhamma.mp3',
#   'folder': 'Internet',
#   'title': 'LivingByDhamma',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-09-15'},
#  {'file': 'Internet/100926_SolvingTheProblem.mp3',
#   'folder': 'Internet',
#   'title': 'Solving The Problem',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'On the importance of seeing Buddhism as a means to solve a problem, understanding that problem and arriving at a solution (Second Life Talk)',
#   'date_from_filename': '2010-09-26'},
#  {'file': 'Internet/091001_GuidedMeditation.mp3',
#   'folder': 'Internet',
#   'title': '',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-10-01'},
#  {'file': 'Internet/100508_MahasiDC1.mp3',
#   'folder': 'Internet',
#   'title': 'Dhammacakkappavattana Sutta',
#   'album': 'Internet',
#   'year': '',
#   'comment': "Reading from Mahasi Sayadaw's DIscourse on the Dhammacakkappavattana Sutta",
#   'date_from_filename': '2010-05-08'},
#  {'file': 'Internet/100723_QuantumEverydayLife.mp3',
#   'folder': 'Internet',
#   'title': 'Quantum Meditation in Daily Life',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'A talk on meditation in everyday life, including a discussion of how meditation fits well with quantum theory.',
#   'date_from_filename': '2010-07-23'},
#  {'file': 'Internet/100427_Wisdom.mp3',
#   'folder': 'Internet',
#   'title': 'Buddhist Wisdom',
#   'album': 'Internet',
#   'year': '',
#   'comment': "Practical teaching on the attainment of wisdom in line with the Buddha's teaching.",
#   'date_from_filename': '2010-04-27'},
#  {'file': 'Internet/130313_SLGuidedAndQuestions.mp3',
#   'folder': 'Internet',
#   'title': 'Second Life Meditation and Questions',
#   'album': '',
#   'year': '2013',
#   'comment': 'Guided meditation at the Buddha Centre in Second Life and Questions and Answers',
#   'date_from_filename': '2013-03-13'},
#  {'file': 'Internet/100511_Goodness.mp3',
#   'folder': 'Internet',
#   'title': 'Ten Ways of Practicing Goodness',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'Ten Ways of Practicing Goodness',
#   'date_from_filename': '2010-05-11'},
#  {'file': 'Internet/110123_MeditationOnLife.mp3',
#   'folder': 'Internet',
#   'title': 'Meditation On Reality',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'Leading guided meditation into the nature of reality.',
#   'date_from_filename': '2011-01-23'},
#  {'file': 'Internet/100922_Purification.mp3',
#   'folder': 'Internet',
#   'title': 'Path of Purification',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'Second Life talk on the seven stages of purification.',
#   'date_from_filename': '2010-09-22'},
#  {'file': 'Internet/091105_CoreBuddhism.mp3',
#   'folder': 'Internet',
#   'title': 'Hardcore Buddhism',
#   'album': 'Internet',
#   'year': '',
#   'comment': "What's really important.",
#   'date_from_filename': '2009-11-05'},
#  {'file': 'Internet/090929_SevenPaths.mp3',
#   'folder': 'Internet',
#   'title': 'SevenPaths',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-09-29'},
#  {'file': 'Internet/101223_ScientificInquiry.mp3',
#   'folder': 'Internet',
#   'title': 'Scientific Inquiry',
#   'album': 'Internet',
#   'year': '',
#   'comment': "On how the Buddha's teaching is best seen as a true scientific inquiry (Second Life).",
#   'date_from_filename': '2010-12-23'},
#  {'file': 'Internet/091020_BeingBuddhist.mp3',
#   'folder': 'Internet',
#   'title': 'BeingBuddhist',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2009-10-20'},
#  {'file': 'Internet/100821_ProblemsForMonksAndLay.mp3',
#   'folder': 'Internet',
#   'title': '',
#   'album': 'Internet',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2010-08-21'},
#  {'file': 'Internet/091103_Upakilesa.mp3',
#   'folder': 'Internet',
#   'title': 'The Sixteen Subtle Defilements  Artist:',
#   'album': 'Internet',
#   'year': '',
#   'comment': 'Sixteen reasons why we cannot be free from suffering.',
#   'date_from_filename': '2009-11-03'},
#  {'file': 'Internet/100817_DependantOrigination.mp3',
#   'folder': 'Internet',
#   'title': 'Practical Dependant Origination',
#   'album': 'Internet',
#   'year': '',
#   'comment': "On the relationship between the Buddha's teaching on dependant origination and one's meditation practice.",
#   'date_from_filename': '2010-08-17'},
#  {'file': 'Live/20160723_0056_livestream.mp3',
#   'folder': 'Live',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2016-07-23'},
#  {'file': 'Live/20170128_0158_livestream.mp3',
#   'folder': 'Live',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2017-01-28'},
# ...
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-03-22'},
#  {'file': 'Visuddhimagga/151025_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-10-25'},
#  {'file': 'Visuddhimagga/150823_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-08-23'},
#  {'file': 'Visuddhimagga/150531_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-05-31'},
#  {'file': 'Visuddhimagga/150809_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-08-09'},
#  {'file': 'Visuddhimagga/150628_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-06-28'},
#  {'file': 'Visuddhimagga/150426_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-04-26'},
#  {'file': 'Visuddhimagga/151115_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-11-15'},
#  {'file': 'Visuddhimagga/150315_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-03-15'},
#  {'file': 'Visuddhimagga/151129_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-11-29'},
#  {'file': 'Visuddhimagga/151018_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '151018_vism',
#   'album': '',
#   'year': '2015',
#   'comment': '',
#   'date_from_filename': '2015-10-18'},
#  {'file': 'Visuddhimagga/150301_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-03-01'},
#  {'file': 'Visuddhimagga/151101_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-11-01'},
#  {'file': 'Visuddhimagga/160103_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2016-01-03'},
#  {'file': 'Visuddhimagga/150802_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-08-02'},
#  {'file': 'Visuddhimagga/150705_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-07-05'},
#  {'file': 'Visuddhimagga/150719_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-07-19'},
#  {'file': 'Visuddhimagga/150712_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-07-12'},
#  {'file': 'Visuddhimagga/150726_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-07-26'},
#  {'file': 'Visuddhimagga/150412_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-04-12'},
#  {'file': 'Visuddhimagga/150816_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-08-16'},
#  {'file': 'Visuddhimagga/150510_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-05-10'},
#  {'file': 'Visuddhimagga/150308_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-03-08'},
#  {'file': 'Visuddhimagga/150614_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-06-14'},
#  {'file': 'Visuddhimagga/150621_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-06-21'},
#  {'file': 'Visuddhimagga/150913_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-09-13'},
#  {'file': 'Visuddhimagga/160117_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2016-01-17'},
#  {'file': 'Visuddhimagga/150503_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-05-03'},
#  {'file': 'Visuddhimagga/150607_vism.mp3',
#   'folder': 'Visuddhimagga',
#   'title': '',
#   'album': '',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2015-06-07'},
#  {'file': 'ask-a-monk/110510_BenefitOfPastLives.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'The Benefit of Remembering Past Lives',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': '"we r what we were & we will b what we r." Would it not be helpful to know our past life to know who we r now to enable us to be who we will be?',
#   'date_from_filename': '2011-05-10'},
#  {'file': 'ask-a-monk/110813_Euthanasia.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'Ask A Monk: Euthanasia',
#   'album': '',
#   'year': '',
#   'comment': 'When, if ever, is euthanasia an alternative to natural death?',
#   'date_from_filename': '2011-08-13'},
#  {'file': 'ask-a-monk/111031_eating-meditating.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'Ask A Monk: Eating and meditation',
#   'album': '',
#   'year': '',
#   'comment': 'Question asked on our weekly radio broadcast at radio.sirimangalo.org',
#   'date_from_filename': '2011-10-31'},
#  {'file': 'ask-a-monk/111031_drowsiness-meditation.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'When tired, is it better to sleep or meditate?',
#   'album': '',
#   'year': '',
#   'comment': 'Question asked on our weekly radio broadcast at radio.sirimangalo.org',
#   'date_from_filename': '2011-10-31'},
#  {'file': 'ask-a-monk/110510_Paths.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'Choosing Paths',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': 'Thank you for teaching. I find my interest in reading, and focus in Zen, also Tibetan Buddhism, and Christianity. Interest in Islam, and Sufi writings. Paths cause me to wonder if I will have to choose or may I learn from various paths. Bless you.',
#   'date_from_filename': '2011-05-10'},
#  {'file': 'ask-a-monk/111026_idol-worship.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'Ask A Monk: Why do people think Buddhists are idol worshippers?',
#   'album': '',
#   'year': '',
#   'comment': 'Question asked on our weekly radio broadcast at radio.sirimangalo.org',
#   'date_from_filename': '2011-10-26'},
#  {'file': 'ask-a-monk/110510_Suffering.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'Developed Societies vs. Tribal Societies',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': 'Do you feel there is less suffering in America where it is almost impossible not to find food because of our society on knowledge that we made existent, or living in our natural environment unequipped with fur & without a society, but rather tribes',
#   'date_from_filename': '2011-05-10'},
#  {'file': 'ask-a-monk/110510_NirvanaSamsaraSelfishness.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'Distinguishing Nirvana From Samsara and Selfishness from Benefit',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': 'i want to ask about non-duality...when one doesnt distinguish the 2 realms of samsara and nirvana then their is no "goal". So my question is, is wanting to trancsend re-birth selfish?',
#   'date_from_filename': '2011-05-10'},
#  {'file': 'ask-a-monk/110623_Pests.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'Dealing With Pests, Violence, Etc.',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': 'On mindful ways to deal with difficult situations involving the physical well-being of oneself and other living beings. ',
#   'date_from_filename': '2011-06-23'},
#  {'file': 'ask-a-monk/111031_meditate-or-study.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'Should one meditate or study more?',
#   'album': '',
#   'year': '',
#   'comment': 'Question asked on our weekly radio broadcast at radio.sirimangalo.org',
#   'date_from_filename': '2011-10-31'},
#  {'file': 'ask-a-monk/111026_children-meditation.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'Ask A Monk: Teaching meditation to children',
#   'album': '',
#   'year': '',
#   'comment': 'Question asked on our weekly radio broadcast at radio.sirimangalo.org',
#   'date_from_filename': '2011-10-26'},
#  {'file': 'ask-a-monk/110707_Pain.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'Dealing With Pain and Suffering',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': 'What to do when you have pain in meditation, and how to use suffering as a vehicle towards enlightenment.',
#   'date_from_filename': '2011-07-07'},
#  {'file': 'ask-a-monk/110612_Hospice.mp3',
#   'folder': 'ask-a-monk',
#   'title': '',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2011-06-12'},
#  {'file': 'ask-a-monk/110725_Exercise.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'Ask A Monk: Physical Exercise',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': 'On the role of physical exercise in the life of an enlightened being.',
#   'date_from_filename': '2011-07-25'},
#  {'file': 'ask-a-monk/110510_FallingAsleep.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'Falling Asleep While Meditating',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': 'Hello, i started meditating a while ago. However i find it difficult not to fall asleep during meditation. Any tips how to be at rest but focust and awake? Thank you. Kind regards',
#   'date_from_filename': '2011-05-10'},
#  {'file': 'ask-a-monk/110510_PartnerResistance.mp3',
#   'folder': 'ask-a-monk',
#   'title': "Partner's Resistance to Meditation",
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': "I've been studying the teachings and meditation for a few months now. But my partner doesn't like it and makes me feel bad, like I'm doing something wrong as a person in general. Even if I'm more compassionate towards others.. Do you have any advice?",
#   'date_from_filename': '2011-05-10'},
#  {'file': 'ask-a-monk/110510_AfterNibbana.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'After Nirvana',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': 'When you reach nirvana must you still continue to mediate or has all the mind training been done. If not is there something to achieve after nirvana?',
#   'date_from_filename': '2011-05-10'},
#  {'file': 'ask-a-monk/110510_EnvyCompetitiveness.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'Envy and Competitiveness',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': 'Envy / competitiveness. Unhealthy states, but alas common. Remedy suggestions?',
#   'date_from_filename': '2011-05-10'},
#  {'file': 'ask-a-monk/110813_holocaust.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'Ask A Monk: Karma in a Holocaust',
#   'album': '',
#   'year': '',
#   'comment': 'How does the theory of karma apply to mass holocausts?',
#   'date_from_filename': '2011-08-13'},
#  {'file': 'ask-a-monk/110606_Addicts.mp3',
#   'folder': 'ask-a-monk',
#   'title': '',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2011-06-06'},
#  {'file': 'ask-a-monk/110510_Humour.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'Humour In Buddhism',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': 'What is the Buddhist view on humor? Is there a place in Buddhist practice for unharmful joke-telling, etc.?',
#   'date_from_filename': '2011-05-10'},
#  {'file': 'ask-a-monk/110510_Addiction.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'Addiction To Pornography and Masturbation',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': "Hello Yuttadhammo, my question is, Through meditation, could I learn to control my mind in a way that would enable me to destroy an addiction, or addictive tendencies? I'm addicted to pornography and masturbation. It's ruining my life, can you help?",
#   'date_from_filename': '2011-05-10'},
#  {'file': 'ask-a-monk/110707_Death.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'When Someone Dies',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': 'What a Buddhist (or any high-minded person) should do when someone dies.',
#   'date_from_filename': '2011-07-07'},
#  {'file': 'ask-a-monk/110626_ExperiencingReality.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'The Experience of Reality',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': 'On experiencing reality through the meditation practice, and how meditators sometimes mistake this for a sign of improper practice.',
#   'date_from_filename': '2011-06-26'},
#  {'file': 'ask-a-monk/111026_AAM-military-service.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'How do buddhists view military service?',
#   'album': '',
#   'year': '',
#   'comment': 'Question asked on our weekly radio broadcast at radio.sirimangalo.org',
#   'date_from_filename': '2011-10-26'},
#  {'file': 'ask-a-monk/111031_intellectual-realizations.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'Ask A Monk: Are the realizations of impermanence, suffering and non-self intellectual?',
#   'album': '',
#   'year': '',
#   'comment': 'Question asked on our weekly radio broadcast at radio.sirimangalo.org',
#   'date_from_filename': '2011-10-31'},
#  {'file': 'ask-a-monk/111026_remember-past-lives.mp3',
#   'folder': 'ask-a-monk',
#   'title': "why don't we remember past lives?",
#   'album': '',
#   'year': '',
#   'comment': 'Question asked on our weekly radio broadcast at radio.sirimangalo.org',
#   'date_from_filename': '2011-10-26'},
#  {'file': 'ask-a-monk/110510_StomachNose.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'The Mind in the Stomach, Breathing Through the Nose',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': "When you say our mind shouldn't be in our head but in our stomach when we contemplate rising and falling what do you mean? can you elaborate it more? -- When meditating how to breathe? Can only breathe through your nose or inhaled through the nose exhale through your mouth? Thanks and Sorry for bad english...",
#   'date_from_filename': '2011-05-10'},
#  {'file': 'ask-a-monk/110529_Vegetarianism.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'A Buddhist Take on Vegetarianism',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': 'Answering the question of whether Buddhists should be vegetarian, and how killing, wanting, buying and eating meat differ.',
#   'date_from_filename': '2011-05-29'},
#  {'file': 'ask-a-monk/110510_Divorce.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'Dealing With Divorce',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': 'Bhante can you help me? my parents are divorced so i am sad in the last months so i want you to help me what should i do?',
#   'date_from_filename': '2011-05-10'},
#  {'file': 'ask-a-monk/110606_Dreams.mp3',
#   'folder': 'ask-a-monk',
#   'title': '',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': '',
#   'date_from_filename': '2011-06-06'},
#  {'file': 'ask-a-monk/110115_Paths.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'Choosing A Path',
#   'album': 'AskAMonk',
#   'year': '',
#   'comment': 'Will I have to choose or may I learn from various paths?',
#   'date_from_filename': '2011-01-15'},
#  {'file': 'ask-a-monk/111026_00016.MTS.mp4.mp3',
#   'folder': 'ask-a-monk',
#   'title': "Ask A Monk: It's not better to suffer in future lives instead of reaching enlightenment and not live anymore?",
#   'album': '',
#   'year': '',
#   'comment': 'Question asked on our weekly radio broadcast at radio.sirimangalo.org',
#   'date_from_filename': '2011-10-26'},
#  {'file': 'ask-a-monk/111031_lying-down.mp3',
#   'folder': 'ask-a-monk',
#   'title': 'Ask A Monk: Is it wrong to meditate lying down?',
#   'album': '',
#   'year': '',
#   'comment': 'Question asked on our weekly radio broadcast at radio.sirimangalo.org',
#   'date_from_filename': '2011-10-31'}]

# %%
with open('metadata_old_feed.json', 'w') as f:
    f.write(json.dumps(res))
